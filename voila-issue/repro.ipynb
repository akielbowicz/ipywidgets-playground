# %%
# !voila --version
# Out:
# 0.5.4

# %%
import ipywidgets as w

# %%
text = "This is a code cell with HTMLMath: $E = m c^2$"

# %%
w.HTMLMath(text)
# Out:
# HTMLMath(value='This is a code cell with HTMLMath: $E = m c^2$')

# %% [markdown]
# This is a markdown cell with math: $E = m c^2$
