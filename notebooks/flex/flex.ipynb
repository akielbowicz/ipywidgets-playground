# %%
import ipywidgets as w

# %%
lip="""
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries

Lorem ipsum is placeholder text commonly used in the graphic, print, and publishing industries
"""

# %%
ta=w.HTML(f"<p>{lip}</p>")

# %%
b = w.Box([ta],style={"background":"red"})

# %%
o = w.Box([b])

# %%
o
# Out:
# Box(children=(Box(children=(HTML(value='<p>\nLorem ipsum is placeholder text commonly used in the graphic, pri…

# %%
o.layout = w.Layout(width="100%",height="auto",border="2px solid", flex="1 0 auto", display="flex")

# %%
b.layout = w.Layout(width="70%",height="100%", border="1px dotted")

# %%
b.add_class("bubble")
# Out:
# Box(children=(HTML(value='<p>\nLorem ipsum is placeholder text commonly used in the graphic, print, and publis…

# %%
# %%html
# <style>
# .bubble {
#     border-radius: 2rem 2rem 2rem 0
# }
# </style>
# Out:
# <style>
# .bubble {
#     border-radius: 2rem 2rem 2rem 0
# }
# </style>

# %%
ta.layout=w.Layout(width="100%", overflow="hidden", padding="1rem")

# %%
app = w.VBox([o]*10, layout=w.Layout(height="400px", display="flex", flex_flow="column", overflow="auto scroll"))
app
